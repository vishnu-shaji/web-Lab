# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
p = ([100,200,250,400,300,450,500])

# %%
q = ([12,14,16,18,20,22,24])

# %%
plt.plot(p, q)

# %%
plt.xlabel('sales')
# Out:
# Text(0.5, 0, 'sales')

# %%
plt.ylabel('Temperature in degree celcius')
# Out:
# Text(0, 0.5, 'Temperature in degree celcius')
